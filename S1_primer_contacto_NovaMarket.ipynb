# %% [markdown]
# # Primer Contacto con datos NovaMarket

# %% [markdown]
# ### Librerias y carga del dataset

# %%
import pandas as pd
df = pd.read_csv('NovaMarket_datos_crudos.csv')
df.head()
# Out:
#   id_pedido id_cliente fecha_compra   canal       ciudad  codigo_postal  \
# 0    P00383      C0276   2026-01-03     App  Bucaramanga          68001
# 1    P00403      C0167    6/12/2026     Web         Cali          76001
# 2    P00403      C0167    6/12/2026     Web         Cali          76001
# 3    P00450      C0128   07/09/2026     App  bucaramanga          68001
# 4    P00449      C0304   2025-07-19  Tienda       Bogotá           8001
#
#   categoria_producto      producto     precio  unidades  edad_cliente  \
# 0            Belleza      Camiseta -1742611.0         4           -19
# 1           Deportes      Cafetera  1828583.0         2            23
# 2           Deportes      Cafetera  1828583.0         2            23
# 3        electronica   Set bloques   787178.0         6            69
# 4            Belleza  Audífonos BT   357231.0         5            67
#
#                 correo nivel_satisfaccion fecha_actualizacion_stock
# ...

# %% [markdown]
# ## Exploración Dataset

# %% [markdown]
# ### Dimensiones

# %%
df.shape
# Out:
# (620, 14)

# %% [markdown]
# ### Primeras filas

# %%
df.head()
# Out:
#   id_pedido id_cliente fecha_compra   canal       ciudad  codigo_postal  \
# 0    P00383      C0276   2026-01-03     App  Bucaramanga          68001
# 1    P00403      C0167    6/12/2026     Web         Cali          76001
# 2    P00403      C0167    6/12/2026     Web         Cali          76001
# 3    P00450      C0128   07/09/2026     App  bucaramanga          68001
# 4    P00449      C0304   2025-07-19  Tienda       Bogotá           8001
#
#   categoria_producto      producto     precio  unidades  edad_cliente  \
# 0            Belleza      Camiseta -1742611.0         4           -19
# 1           Deportes      Cafetera  1828583.0         2            23
# 2           Deportes      Cafetera  1828583.0         2            23
# 3        electronica   Set bloques   787178.0         6            69
# 4            Belleza  Audífonos BT   357231.0         5            67
#
#                 correo nivel_satisfaccion fecha_actualizacion_stock
# ...

# %% [markdown]
# ### Información general

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_pedido                  620 non-null    str
#  1   id_cliente                 620 non-null    str
#  2   fecha_compra               620 non-null    str
#  3   canal                      620 non-null    str
#  4   ciudad                     589 non-null    str
#  5   codigo_postal              620 non-null    int64
#  6   categoria_producto         620 non-null    str
#  7   producto                   620 non-null    str
#  8   precio                     599 non-null    float64
#  9   unidades                   620 non-null    int64
#  10  edad_cliente               620 non-null    int64
#  11  correo                     516 non-null    str
#  12  nivel_satisfaccion         574 non-null    str
#  13  fecha_actualizacion_stock  620 non-null    str
# ...

# %% [markdown]
# ### Estadísticas descriptivas

# %%
df.describe(include="all")
# Out:
#        id_pedido id_cliente fecha_compra   canal       ciudad  codigo_postal  \
# count        620        620          620     620          589     620.000000
# unique       600        311          495       3           19            NaN
# top       P00403      C0043   15/11/2027  Tienda  bucaramanga            NaN
# freq           2          6            9     224           58            NaN
# mean         NaN        NaN          NaN     NaN          NaN   31917.129032
# std          NaN        NaN          NaN     NaN          NaN   30339.586863
# min          NaN        NaN          NaN     NaN          NaN    5001.000000
# 25%          NaN        NaN          NaN     NaN          NaN    8001.000000
# 50%          NaN        NaN          NaN     NaN          NaN   13001.000000
# 75%          NaN        NaN          NaN     NaN          NaN   68001.000000
# max          NaN        NaN          NaN     NaN          NaN   76001.000000
#
# ...

# %% [markdown]
# ### Valores Faltantes

# %%
df.isnull().sum()
# Out:
# id_pedido                      0
# id_cliente                     0
# fecha_compra                   0
# canal                          0
# ciudad                        31
# codigo_postal                  0
# categoria_producto             0
# producto                       0
# precio                        21
# unidades                       0
# edad_cliente                   0
# correo                       104
# nivel_satisfaccion            46
# fecha_actualizacion_stock      0
# dtype: int64

# %% [markdown]
# ### Duplicados

# %%
df.duplicated().sum()
# Out:
# np.int64(20)

# %% [markdown]
# ### Tipos de datos

# %%
df.dtypes
# Out:
# id_pedido                        str
# id_cliente                       str
# fecha_compra                     str
# canal                            str
# ciudad                           str
# codigo_postal                  int64
# categoria_producto               str
# producto                         str
# precio                       float64
# unidades                       int64
# edad_cliente                   int64
# correo                           str
# nivel_satisfaccion               str
# fecha_actualizacion_stock        str
# dtype: object

# %% [markdown]
# ## Primeras Impresiones

# %% [markdown]
# #### ¿Cuántos registros y variables hay?
#
# El dataset contiene:
#
# 620 registros (filas)
# 14 variables (columnas)
#
# #### ¿Qué tipos detectas?
#
# Se identifican tres tipo de datos, el cual es string (str) que son las variables de texto, int64 que son las variables numéricas enteras y por ultimo float64 que son las variables numéricas decimales
#
#
# #### ¿Qué problemas saltan a la vista (vacíos, formatos raros, posibles duplicados)?
#
# Existen varios valores faltantes, identifico que hay 20 registros duplicados, existen inconsistencias en la escritura de algunas categorías dado que se utilizan mayúsculas, minúsculas y acentos, es decir se escribe la misma palabra de diferente manera, las fechas deberian estar como datetime y no str, existen unidades inusuales como precios y edades negativas

# %% [markdown]
# ## Clasifique al menos 5 variables por su tipo y nivel de medición.

# %% [markdown]
# ####  id_pedido:
# Tipo de variable: str
#
# Nivel Medición: Nominal.
#
# #### precio:
#
# Tipo de variable: Numérica Continua (float64)
#
# Nivel Medición: Razón
#
# #### unidades:
#
# Tipo de variable: Numérica discreta (int64)
#
# Nivel Medición: Razón
#
# #### fecha_compra:
#
# Tipo de variable: str, respresenta en este caso una fecha
#
# Nivel Medición: Intervalo
#
# #### nivel_satisfaccion
#
# Tipo de variable: str
#
# Nivel Medición: Ordinal
